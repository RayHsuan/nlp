# %%
# !python --version
# Out:
# Python 3.6.12 :: Anaconda, Inc.

# %%
# !pip install -q -U pip
# !pip install -q numpy
# !pip install -q pandas
# !pip install -q ckiptagger
# !pip install -q tqdm
# !pip install -q tensorflow==1.14.0
# !pip install -q ipywidgets

# %%
import pandas as pd
import numpy as np

from ckiptagger import WS, POS
from tqdm.notebook import tqdm
# Out:
# C:\Users\User\Anaconda3\envs\nlp\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\User\Anaconda3\envs\nlp\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\User\Anaconda3\envs\nlp\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\User\Anaconda3\envs\nlp\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\User\Anaconda3\envs\nlp\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\User\Anaconda3\envs\nlp\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df_train = pd.read_csv('news_clustering_train.tsv', sep='\t')
df_test = pd.read_csv('news_clustering_test.tsv', sep='\t')

# %%
df_train
# Out:
#       index class                            title
# 0         0    體育         亞洲杯奪冠賠率：日本、伊朗領銜 中國竟與泰國並列
# 1         1    體育        9輪4球本土射手僅次武磊 黃紫昌要搶最強U23頭銜
# 2         2    體育             如果今年勇士奪冠，下賽季詹姆斯何去何從？
# 3         3    體育            超級替補！科斯塔本賽季替補出場貢獻7次助攻
# 4         4    體育          騎士6天里發生了啥？從首輪搶七到次輪3-0猛龍
# ...     ...   ...                              ...
# 1795   1795    遊戲  LOL：麻辣香鍋韓服Rank不合成打野刀？電刀巨魔新套路連勝中
# 1796   1796    遊戲            穩住，我們能贏！因為我們擁有這種強大的力量
# 1797   1797    遊戲          騰訊是怎樣毀掉《鬥戰神》這款可能成神的作品的？
# 1798   1798    遊戲                   LOL你不知道的黑科技打法！
# 1799   1799    遊戲                 遊戲拳皇各代的劇情都在講些什麼？
#
# [1800 rows x 3 columns]

# %%
df_test
# Out:
#      index class                                title
# 0     1800    體育                   如果騎士火箭進入總決賽，誰的勝算大？
# 1     1801    體育             從個人競技狀態來看，三個階段的詹姆斯，哪個最強？
# 2     1802    體育       騎士總冠軍！地球人誰能阻擋詹姆斯？史上最佳就是他！打服所有人
# 3     1803    體育                   詹姆斯絕殺，騎士3比0，猛龍懷疑人生
# 4     1804    體育  騎士和步行者戰成搶七險勝，而猛龍即將被橫掃，步行者跟猛龍的區別在哪裡？
# ..     ...   ...                                  ...
# 595   2395    遊戲                           如何玩好《陰陽師》？
# 596   2396    遊戲                        網賺——玩遊戲網賺也不錯呦
# 597   2397    遊戲                          迷你世界怎麼跳四段跳？
# 598   2398    遊戲       DNF5000罐子挑戰遠古遺願，玩家最後只說了兩個字「坑爹」
# 599   2399    遊戲                     穿越火線那些被玩家吐槽的不足之處
#
# [600 rows x 3 columns]

# %%
train_titles = {row['index']: row['title'] for _, row in df_train.iterrows()}
train_classes = {row['index']: row['class'] for _, row in df_train.iterrows()}

test_titles = {row['index']: row['title'] for _, row in df_test.iterrows()}
test_classes = {row['index']: row['class'] for _, row in df_test.iterrows()}

# %%
all_news_class = ['體育', '財經', '科技', '旅遊', '農業', '遊戲']

# %% [markdown]
# # 斷詞 + POS

# %%
ws = WS('./data/')
pos = POS('./data/')

# %%
train_title_cuts = {}
#word_s, word_p = None, None
for index, title in tqdm(train_titles.items()):
    # YOUR CODE HERE
    #print(title)
    word_s = ws([title],
    sentence_segmentation =True)
    #print(word_s)
    
    word_p = pos(word_s)
    #print(word_p)
    #break
    # END YOUR CODE
    train_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1800.0), HTML(value='')))

# %%
test_title_cuts = {}
for index, title in tqdm(test_titles.items()):
    # YOUR CODE HERE
    word_s = ws([title],sentence_segmentation =True)
    word_p = pos(word_s)
    # END YOUR CODE
    test_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=600.0), HTML(value='')))

# %%
train_title_cuts[120]
# Out:
# [('國腳', 'Na'),
#  ('張呈棟', 'Nb'),
#  ('：', 'COLONCATEGORY'),
#  ('從', 'D'),
#  ('沒', 'D'),
#  ('想', 'VE'),
#  ('過', 'Di'),
#  ('自己', 'Nh'),
#  ('會', 'D'),
#  ('出', 'VC'),
#  ('一', 'Neu'),
#  ('本', 'Nf'),
#  ('書', 'Na')]

# %% [markdown]
# # Bag of Words (BOW)

# %%
word2index = {}
index2word = {}
# 產生字與index對應的關係
# YOUR CODE HERE
i = 0
for lst_word_pos in train_title_cuts.values():
    for w, p in lst_word_pos:
        if w not in word2index:
            word2index[w] = i
            index2word[i] = w
            i += 1
# END YOUR CODE

# %%
word2index['溫暖']
# Out:
# 1512

# %%
index2word[1512]
# Out:
# '溫暖'

# %%
def get_bow_vector(pairs, word2index):
    # YOUR CODE HERE
    vector = np.zeros(len(word2index))
    for w,p in pairs:
        if w in word2index:
            vector[word2index[w]] += 1

    return vector
    # END YOUR CODE

# %%
get_bow_vector(train_title_cuts[120], word2index)
# Out:
# array([0., 0., 1., ..., 0., 0., 0.])

# %% [markdown]
# # 排除較無意義的詞性

# %%
pos_analysis = {}
for _, pairs in train_title_cuts.items():
    for word, flag in pairs:
        if flag not in pos_analysis:
            pos_analysis[flag] = set()
        pos_analysis[flag].add(word)

for flag, words in pos_analysis.items():
    print(flag, ':', list(words)[:100])
    print('=======================')
# Out:
# Nb : ['余小C', '雅桑克萊', '郎平', '約翰塞納', '2018-5-6', '招行', '重渡溝', '阿里雲', '帕克成', '后羿', '維韋杜詹霍', '賞月夜', '戈麥斯', '瑞和寶', '綠軍', '林斌', '切沃', '科爾', '烏迪內斯', '阿珂', '斯威', '沃爾瑪', '洛瑞', '郭春林', '查理芒格', '伯德', '劉詩雯', '勒布朗', 'NBA', '芒格', '石川佳純', '韓長賦', '西蒙斯', 'm15', '鎧單', '盧克肖', '里皮', 'S10', '保羅', '塔克', '英超', '扎哈維', '建聯', '唐汪鎮', '比格利亞', '姚振華', '克洛普', '德羅巴', '恆大', '上港', '朱之文', '何雯娜', '楊帆', '夢琪', '韋德', '奧拉朱旺遠', '喬丹', '馬克', '楊柳夏', '劉歡', '西游', '布茲德里克', '周評', '萬孚', '康德', '鄭眼', '朱婷', '小詹皇', '張掖篇', '木歷', '艷武漢', '李秋平', '朱嘯虎', '景泰石', '泰倫盧', '餘額寶', '梅西', '金英權', '曼聯', '賈躍亭', '德羅', '皇馬', '慧商', '華創', '卡拉斯科', '斯諾克', '阿木', '衛報', 'V10', '溫氏', '泰拳王西', '加威廉', '切爾西', '人民日報', '施泰納', '紫鑫', '殺里', '清華大學生', '盼保', '張大仙']
# =======================
# Na : ['中藥', '雨水', '湖怪', '薊馬', '傳奇', '可能', '電腦', '球童', '糧', '美味', '建築', '年齡', '獎勵', '蜂群', '好處', '金華人', '紅薯苗', '養殖戶', '醫藥', '回票', '迷宮', '潛質', '生態環境', '地球', '投資', '白鶴', '效果', '鯽魚塘頭價', '規範', '演講', '品種', '持續性', '魔鎧', '車', '姐', '自行車', '果農', '櫻花', '馬拉松賽', '銀聯卡', '髮力', '臍橙', '券商股', '網易商', '爆棚', '良機', '大蒜', '高溫', '陰影', '墨', '須彌', '球員', '山川', '全媒體', '河', '國米球', '預言家', '公路', '大獎賽', '塔', '主義', '貨幣', '成功率', '重點', '英超', '鬥戰神', '點', '皇家', '盤感', '趨勢', '市值', '女', '玻璃', '銅', '風情', '機械', '增速', '數字幣', '藍花楹', '青山綠水', '利潤率', '風景', '北京人', '冰', '死神', '餘額', '國家', '網約車', '反擊戰', '疾病', '狗托', '搏擊', '單打', '球技', '記', '飛車', '配額', '鰐魚', '豬價', '庭院']
# =======================
# COLONCATEGORY : [':', '：']
# =======================
# Nc : ['綿竹', '招行', '超京', '支行', '球館', '九寨溝', '黃鶴樓', '聯合村', '哈尼梯田', '自治縣', '巴黎', '行協', '西安', '國道', '年畫村', '莊浪', '聊城', '高校', '北控', '海口', '科內利亞諾', '上位', '協會', '龍江', '泰國', '武漢', '農場', '萊加內斯', '韓國', '陽江', '荒野', '溫州', '小學', '巨蛋', '華鎣', '公司', '吉爾吉斯斯坦', '天際', '保級區', '陽朔', '培田', '債市', '河北', '東南亞', '桂林', '實驗室', '茜溪', '牛市', '煙台', '保護區', '蒼穹', '河州', '月季園', '華僑城', '嘉陵江', '趙集鎮', '日照市', '果嶺', '梅縣', '文山', '機場', '家鄉', '上海', '去處', '北海道', '北侖', '瀋陽', '柯橋', '早市', '香格里拉', '圭塘', '國外', '嵐皋', '濱', '金融城', '北京', '冠格局', '尼泊爾', '合陽縣', '四國', '滎經縣', '川藏', '酒店', '下轄縣', '利物浦', '地產界', '內內', '城市', '人間', '吐魯番', '湘西', '咖啡蘭', '電競站', '災房', '附近', '耿店村', '中', '港交所', '南極', '華山']
# =======================
# PAUSECATEGORY : ['、']
# =======================
# VB : ['導航', '執教', '扣分', '罵屌絲', '融資', '退改', '分組', '再見', '加工', '解惑', '加持', '分紅', '充氣', '護航', '助威', '解體', '相比', '計算出來', '入賬', '收回來', '站台', '拍照', '抓來', '鍍金', '復仇', '鋪平', '領銜', '退款', '加冕', '退貨', '定位', '解密', '解圍', '分段', '開戰', '上架', '充飢', '加起來', '通話', '提前', '一網打盡', '加油', '罰款', '效力', '應對', '代打', '騙錢']
# =======================
# WHITESPACE : [' ']
# =======================
# D : ['總算', '雙雙', '驟然', '是否', '一定', '當下', '常', '仍', '或許', '隆', '頻', '至今', '全面', '盡情', '本來', '很少', '不會', '可能', '略', '曾經', '如何', '要', '相互', '哈哈', '未必', '會不會', '未', '進一步', '到底', '不再', '不可以', '大幅', '親身', '屢屢', '及時', '重新', '別', '竟然', '還', '皆', '並', '該', '本', '剛', '能否', '仍然', '隨', '不要', '超級', '屢', '永遠', '無可', '盡', '不可', '趁早', '硬生生', '恆', '可', '少', '應當', '已', '好在', '一般', '必', '還可以', '不用', '總是', '已然', '隨地', '會', '冒死', '先', '首', '即將', '究竟', '獨', '多多', '一頭', '搞不好', '趕快', '只有', '一手', '白', '更', '多', '也', '不得不', '難以', '結伴', '千萬', '怎麼', '不', '沒想到', '應該', '大規模', '從', '必須', '又', '每', '再度']
# =======================
# P : ['如', '離', '給', '除', '將', '自從', '對', '往', '等', '和', '臨', '比如', '為', '用', '以', '像', '跟', '在', '按', '遭', '繼', '趁著', '待', '比', '憑', '針對', '從', '幫', '與', '就', '自', '當', '除了', '根據', '靠', '關於', '隨', '於', '向', '至', '把', '為了', '隨了', '慘遭', '到', '因', '受', '被', '直至', '距離', '趁']
# =======================
# VG : ['如', '稱得上', '酷似', '投票成', '泛濫成', '作為', '稱作', '建成', '誤認成', '算是', '形成', '為', '做', '堪稱', '竟是', '等於', '賣成', '理解為', '稱為', '像', '化', '當上', '譽為', '彷彿', '算', '屬於', '改造成', '當作', '當成', '名叫', '變成', '做成', '叫', '姓', '疑似', '居', '類似', '當', '充當', '非', '稱', '猶如', '排', '成為', '戰成', '排行', '叫做', '美成', '變', '合成', '應聘', '似', '成', '排名', '並列', '集成', '任', '評選', '屈居', '封號', '升任']
# =======================
# Neu : ['4G+64', '幾百', '400萬', '21', '第十四', '1318', '1299', '萬億', '5.6', '第9', '200萬', '4萬多', '兩', '十萬', '17億', '1900億', '1', '00', '5050', '25', '3000億', '2200', '十三', '13888', '2400', '3-0', '五', '56', '32', '60萬', '10010', '2599', '4.7億', '11', '730萬', '98', '2000', '29', '3', '4', '9-0', '46萬', '第一', '100多', '30萬', '八', '第33', '845', '6.9', '2萬', '一萬', '11.59億', '15', '8', '第3', '5000', '1000萬', '二十', '1.46億', '第114', '億', '1699', '數千萬', '17', '1.1.2', '4.5億', '1300', 'b120', '1300萬', '20萬', '35萬', '115', '54', '450億', '第四十四', '120', '第1', '600', '6', '14億', '2018.', '60多', '一百', '2018.5.6', '千億', '15萬', '千萬', '400', '8.7億', '23萬一', '三千億', '15.60', '60', '百億', '兩四', '100萬', '千', '47億', '十多萬', '2.5']
# =======================
# Nf : ['局', 'K', '則', '對', '群', '遍', '筆', '周', '公里', '頁', '關', '斤', '度', '隻', '頓', '張', '路', '部', '本', '座', '層', '噸', '處', '個', '篇', '年', '檔', '把', '掛', '日', '胎', '位', '些', '分', '槍', '色', '美元', '秒', '句', '批', '台', '週', '道', '株', '點', '名', '英吋', '袋', '輪', '元', '歲', '塊', '項', '串', '次', '股', '米', '所', '輛', '條', '票', '件', '畝', '刻', '樣', '行', '碗', '班', '口', '家', '回', '號', '期', '節', '類', '鍋', '款', '場', '天', '晚', '片', '門', '招', '支', '毛', '番', '種', '套', '隊', '港元', '頭', '戶', '分鐘', '盤', '棵', '屆', '步', '方', '只', '級']
# =======================
# VJ : ['擁有', '珍惜', '不理', '共有', '從事', '佔', '失去', '平', '仇', '看好', '領先', '出身', '為', '逾', '錯過', '過完', '達到', '含有', '發揮', '贊同', '錯失', '分享', '痛失', '值', '富', '新增', '贏得', '僅次', '僅次於', '展望', '曝限', '替代', '耗', '不如', '不到', '大勝', '恪守', '賽', '脫', '共享', '關注', '順應', '輸掉', '喪失', '曬', '抗', '負於', '虧損', '毫無', '懷念', '翻倍', '領略', '高達', '來自', '身臨', '忽略', '領跑', '惜', '震撼到', '衝', '遭遇', '減持', '要價', '服', '維持', '懼怕', '受', '遺傳', '恭喜', '年入', '減', '出', '無', '得', '入圍', '負', '沒有', '煥發', '獲', '歸', '缺', '認識', '自有', '透', '歸屬於', '達', '獨佔', '靠', '看不過去', '持有', '爆發', '入選', '蘊藏', '缺少', '獲得', '惹不起', '發生', '冷落', '充', '享受']
# =======================
# VD : ['給', '賣', '貸款', '輸', '交付', '轉讓', '給予', '搶', '寄予', '分', '贏', '郵給', '配', '補貼', '借', '提供', '速遞', '輸給', '發', '欠', '白送', '付', '禁售', '清繳', '拒賠', '發給', '還', '供應', '收費', '送', '予', '售', '借貸', '發放', '傳', '補繳', '貸', '坑', '支付']
# =======================
# Dfa : ['更為', '頗', '這麼', '有點', '過於', '超', '同樣', '更', '多', '最', '比較', '遠遠', '有些', '十分', '越來越', '遠', '過', '不大', '還', '如此', '好', '較', '非常', '太', '很', '極', '還要']
# =======================
# VH : ['通貨膨脹', '多樣', '發黃', '藥用', '巨大', '健康', '發熱', '全自動', '沒用', '死', '老', '爆炸', '瘋狂', '很少', '功不可', '相關', '雄偉', '如何', '真實', '交流', '酸', '喜聞', '渾濁', '暖', '升級', '美味', '開心', '優越', '急', '可怕', '吉大利', '快速', '富有', '純', '好用', '有用', '淺', '呆呆', '單身', '堅決', '變幻莫測', '火爆', '實際', '開黑', '欠佳', '鮮', '稱霸絕', '沸騰', '盛開', '輕鬆', '理智', '爆棚', '輸球', '多多', '忙', '仿真', '重要', '甜蜜', '多', '完善', '精心', '特殊', '廉價', '連勝', '窮', '平板', '遠', '一目瞭然', '樂享', '完好', '出現', '過時', '流行', '笨', '穩膽', '一樣', '真不少', '精彩', '未果', '同步', '發達', '好意', '上去', '低迷', '面世', '不得了', '繽紛', '時髦', '好好', '值錢', '爆爆', '心酸', '專業', '合作', '富奔', '卸任', '無奈', '大敗', '悠久', '貴']
# =======================
# Cbb : ['因為', '但是', '就算', '反而', '只是', '致', '只有', '若', '要是', '並且', '假如', '不過', '而', '還不如', '縱使', '而是', '並', '不管', '但', '既然', '否則', '跟著', '另外', '只要', '雖然', '不然', '因', '可是', '即使', '不如', '連', '既', '如果', '不僅']
# =======================
# Nd : ['6日', '晚間', '多久', '後期', '7日', '周', '週一', '明', '首日', '今天', '季', '2018年度', '同時', '5月', '晚清', '幾月份', '三國', '30號', '狗年', '過去', '隔年', '5.7日', '初夏', '長期', '00年', '06日', '後', '今夏', '春季', '05月', '當前', '夏天', '10點', '如今', '19年', '當時', '熱天', '小時候', '未來', '90年', '6月', '花季', '現代', '以後', '月季', '隆慶', '1990年', '旺季', '夏季', '雍正', '夏日', '七月份', '明日', '一會', '15日', '昨天', '以前', '8月', '大中', '季度', '13點', '2020年', '春天', '九月', '後來', '米節', '夜', '12日', '2018年', '下旬', '四月', '6旬', '最近', '7號', '一大早', '今日', '中期', '昔日', '目前', '5號', '文化節', '明晚', '5月份', '當年', '晚上', '目後', '春', '半夜', '3月', '最後', '今年', '正月', '5日', '現在', '1點', '夏', '2018', '2019', '五月份', '週二']
# =======================
# VA : ['旅遊', '歸來', '追肥', '旅行', '開車', '避暑', '控股', '掛牌', '一戰', '起飛', '懷孕', '跳', '成交', '加菜', '頂風', '打球', '出發', '回家', '變通', '下雪', '秋遊', '下卡', '相克', '翻曬求籽', '排兵', '搭檔', '釣魚', '掃碼', '升', '打牌', '坐', '觀戰', '飆車', '抓頂', '跑', '睡', '回落', '問世', '輪轉', '開門紅', '上升', '何去何從', '哭', '續交', '澆水', '進城', '倒下', '開團', '代班', '追債', '醫人', '奔', '爭冠', '潛伏', '傳宗接代', '答復', '申遺', '奪冠', '毀號', '求生', '會師', '表態', '下山', '爬山', '大小便', '轉賬', '漂流', '逆襲', '跌', '轉會', '參賽', '擒敵', '挺進', '刮風', '喧囂', '復盤', '隕落', '播種', '亮相', '遊玩', '登場', '爆錘', '降水', '娶妻', '溢出', '下雨', '探秘', '育秧', '逃亡', '種菜', '帶隊', '輪換', '步行', '正名', '收尾', '對陣', '上班', '目不暇接', '降額', '攻堅']
# =======================
# COMMACATEGORY : ['，', ',']
# =======================
# Nes : ['同', '每', '近', '貴', '後', '首', '何', '上', '頭', '前', '各', '另', '該', '本', '某', '下']
# =======================
# QUESTIONCATEGORY : ['？']
# =======================
# VC : ['派出', '刷新', '實行', '踢出', '秒選', '改種', '發明', '買', '助推', '說動', '制裁', '禁', '殺', '死', '開好', '刷爆', '擺出', '舉辦', '豪取', '佔領', '幫助', '使用', '關掉', '縊縮', '接受', '增持', '搬進', '拉', '底背離', '翻', '吃到', '防守', '玩好', '調侃', '擊', '融入', '築牢', '投資', '設置', '奪', '重建', '火遍', '揭密', '留', '花費', '翻譯', '沒用完', '到', '籌劃', '重演', '振興', '實施', '炒比', '應用', '研發', '打爆', '改變', '運用', '挑選出', '摘', '共議', '執行', '坑害', '噴', '攀比', '選', '下調', '攢', '帶動', '融合', '炸', '打掃', '練習', '通', '扣除', '搞', '吹', '刪除', '揭秘', '找', '玩上', '冒充', '開出', '搭配', '捕捉', '住', '喝', '過上', '舉行', '觀看', '擺脫', '點', '投身', '投', '綁定', '摸', '開復', '出裝', '影響', '攜驅']
# =======================
# EXCLAMATIONCATEGORY : ['!', '！']
# =======================
# Di : ['個', '過', '起來', '了', '著']
# =======================
# Nep : ['那', '什麼', '這', '哪', '此', '啥', '其', '其中']
# =======================
# Caa : ['至', 'VS', '還是', '又', '或是', '與', '跟', '到', '或', '比', '和', '或者', '暨', '及']
# =======================
# VCL : ['橫掃', '前往', '穿越', '去', '進', '暗渡', '出', '跌出', '往', '度過', '留在', '走訪', '走過', '重回', '抵達', '登陸', '盤踞', '栽進', '用於', '出發到', '在', '跌至', '上', '回歸', '到達', '回到', '走到', '退出', '過', '回', '進入', '住', '升至', '入', '蒞臨', '前來', '玩遍', '赴', '直達', '穿透', '深入', '走進', '路過', '遠離', '到', '重返', '遊覽', '穿過', '存進', '來到', '走下']
# =======================
# Neqa : ['6%', '15%', '個個', '哪些', '遍', '其他', '一切', '所有', '無數', '一點', '大多數', '百分之八十', '多', '有的', '不少', '很多', '四成', '41.8%', '大量', '大多', '有些', '0.8%', '20%', '那些', '全', '步步', '一處處', '這麼多', '半', '任何', '90%', '其它', '句句', '更多', '多點', '部分', '80%', '滴滴', '10%', '30%', '一些', '三分之一', '9.89%', '12%', '1%', '100%', '1/4', '8%', '67%', '多少', '一半', '許多', '這些']
# =======================
# Nh : ['自己', '自我', '各自', '她', '他', '它', '各位', '我們', '自身', '他們', '別人', '私人', '她們', '大家', '父子倆', '雙方', '對方', '誰', '你們', '小眾', '我', '你', '個人', '屌絲', '俺們', '它們', '本人', '您', '一方', '人家']
# =======================
# FW : ['>', 'K', 'EVO', 'Brian Kelly', 'DASH', '/', 'RPG', 'ios', '5G', 'lck', 'CFO', 'max2', '+', 'QG', ' 展', 'CEO', 'SUP', 'CFPL', 'dota', 'iPhone7', 'eStar', 'Khan', 'steam', 'BTC', 'iPad', 'SSR', 'Mc', 'QM', 'G+', 'vs', '<', 'FPP', 'cpu', '5A', 'RNG', 'GPP', 'QGhappy', 'CP', 'mc', 'ABCC', 'mAh+', 'Minecraft', 'SSG', 'kpl', 'Aurum ', 'Fullestop', 'U23', 'iphone6plus', 'Rookie', 'KPL', ' 利', 'Pro', 'C', 'CPI', 'IOS', '6 10.5', ' 秀', '―', 'FOF', 'ipad', 'GoogleI/O2018', ' 樂', 'MSI', 'QQ', 'OMG', 'CF', 'OB', ' + ', 'QDC', 'msi', 'One', 'NPC', 'AI', 'FF ', 'GuruFocus', 'vip', 'ADC', '4AM', 'LPL', 'HTC', 'numb', 'King James', 'S11', 'EOS', 'wifi', 'Cotswolds', 'Aloha', 'X13', 'iPhone X Plus', 'Credo', 'Lol里', 'CDR', '｜', 'Hello Kitty', 'qq', '2', 'X', 'DNF', '~', 'note5']
# =======================
# SHI : ['像是', '是']
# =======================
# VE : ['想', '說', '想好', '做到', '想起', '見', '准', '要', '確認', '公示', '訴說', '報道', '禁止', '發誓', '允許', '算', '想要', '示範', '查找', '考慮', '回答', '宣佈', '提到', '公佈', '賭', '聯想', '討說', '談', '說明', '廣播', '判罰', '預計', '提醒', '呼', '估值', '精准', '檢測', '言', '提', '看出', '公告', '假設', '告訴', '聽', '慶祝', '賭約', '稱', '防止', '感嘆', '問', '提猜', '證', '看看', '幻想', '安排', '傳聞', '管', '判定', '回顧', '公認', '警惕', '聽到', '申卡', '預測', '深思', '研究', '猜', '查', '預告', '講', '看到', '盛贊', '商量', '調研', '披露', '探討', '認為', '形容', '發佈', '發現', '預期', '承諾', '識別', '爆料', '呼籲', '講解', '反對', '判斷', '預定', '抱怨', '提起', '聽說', '探索', '自嘲', '揭曉', '證明', '見證', '避免', '暗示', '見到']
# =======================
# DE : ['之', '得', '的', '地']
# =======================
# VHC : ['減少', '開', '暫停', '愁壞', '結束', '強化', '下來', '加快', '傷', '告破', '感動', '繁榮', '肥', '凍', '停', '豐富', '破', '斷', '增長', '滿足', '還原', '冷卻', '增加', '機構化', '產生', '增 ', '國際化', '團結', '煩', '規模化', '辛苦', '熱', '麻煩', '平衡', '公開', '現代化', '陷', '可憐', '寶智能化', '壞', '降低', '優化', '擴張', '增強', '恢復', '淡化', '溫暖', '震驚', '縮小', '穩定', '愁死', '變動', '普及']
# =======================
# Ng : ['間', '起', '初', '之間', '底', '前', '之下', '般', '之後', '內', '來', '之上', '上', '之中', '外', '下', '時', '中', '以後', '以下', '後', '之外', '以外', '之內', '裡', '之前', '左右', '以上', '為止', '以來']
# =======================
# VK : ['信', '感謝', '知', '感覺', '害怕', '面臨', '恨', '擔心', '指望', '奇怪', '介意', '需要', '感受', '不忘', '欲', '恐', '抱歉', '意味', '怕', '願', '討厭', '願意', '遇', '忘', '瞭解', '回憶', '喜歡', '覺', '盼', '顯示', '期待', '感覺到', '明白', '理解', '同意', '確定', '小心', '堅持', '意外', '所謂', '有利於', '希望', '忘記', '懂', '依賴', '注意', '需', '放心', '意想不到', '肯定', '想見', '知道', '不滿', '懂得', '懷疑', '流傳', '曲解', '覺得', '遺憾']
# =======================
# Ncd : ['間', '哪兒', '東', '中部', '哪裡', '中間', '內', '東部', '那邊', '上', '外', '底部', '西', '下', '上方', '外面', '一帶', '中', '東方', '哪', '當中', '畔', '對面', '東西部', '邊', '前沿', '這裡', '旁邊', '哪下', '以下', '上面', '那裡', '末端', '方', '裡面', '旁', '裡', '西部']
# =======================
# A : ['中西', '一般', '唯一', '地下', '獨家', '共同', '額外', '基層', '獨門', '歐式', '真正', '小本', '雙', '長途', '超', '多餘', '優質', '麻辣', '單', '常務', '新興', '眾', '同等', '火紅', '國產', '主', '現役', '大幅度', '綜合', '總', '中', '前置', '業餘', '現行', '基礎', '高度', '寶有', '非', '彩色', '後置', '原', '最佳', '重磅', '頭號', '超級', '野生', '新一代', '上上', '二手', '獨角', '乒乓', '必備', '碧藍', '母']
# =======================
# V_2 : ['有']
# =======================
# VL : ['令', '後悔', '不惜', '習慣', '喜好', '甘願', '致', '導致', '使', '故意', '愛好', '便利', '敢', '使得', '開始', '肯', '讓', '持續', '用來', '能', '趨於', '愛']
# =======================
# T : ['吧', '的', '唄', '矣', '啦', '哦', '麼', '去', '來', '哪', '咯', '嘛', '啊', '了', '呢', '嗎']
# =======================
# VI : ['取勝', '驚艷', '著稱', '專用']
# =======================
# DASHCATEGORY : ['—', '-']
# =======================
# I : ['哦', '瑪法里奧']
# =======================
# Dk : ['反過來', '那', '想不到', '那麼', '據聞', '結果', '據說', '外傳']
# =======================
# VF : ['試', '策劃', '帶領', '繼續', '邀', '催', '要求', '打算', '告誡', '逼', '助', '率領', '勸說', '拒', '推選', '擬', '叫', '試試', '拒絕', '止住', '請', '圖', '準備', '鼓勵', '申請', '勸住', '判', '停止']
# =======================
# Da : ['幾乎', '僅', '唯獨', '最多', '只', '足足', '約', '將近', '光', '才', '共', '近', '正好', '幾近', '不下']
# =======================
# PARENTHESISCATEGORY : ['》', '「', '《', '(', '（', '）', '」']
# =======================
# Nv : ['開發', '分銷', '旅遊', '代理', '配置', '管理', '體驗', '抗戰', '增發', '研究', '生產', '絕殺', '護髮', '批發', '買單', '崩潰', '射擊', '訴訟', '回歸', '燃燒', '供電', '防治', '度假', '錄制', '創業', '私募', '輔助', '工作', '登山', '思考', '問', '解救', '組合', '兼職', '安全', '翻譯', '灌籃', '遊樂', '經歷', '疊加', '關聯', '航海', '營銷', '推薦', '判罰', '銷售']
# =======================
# PERIODCATEGORY : ['。', '·']
# =======================
# VAC : ['移動', '集合', '蒸發', '推進', '上演', '動']
# =======================
# Dfb : ['些', '一點', '夠', '極了']
# =======================
# Cab : ['等等', '等']
# =======================
# SEMICOLONCATEGORY : ['；']
# =======================
# Neqb : ['多', '半', '以上']
# =======================
# ETCCATEGORY : ['…']
# =======================
# Cba : ['的話']
# =======================
# DOTCATEGORY : ['.']
# =======================

# %% [markdown]
# |         Type        |     Description    |
# |:-------------------:|:------------------:|
# | A                   | 非謂形容詞         |
# | Caa                 | 對等連接詞         |
# | Cab                 | 連接詞，如：等等   |
# | Cba                 | 連接詞，如：的話   |
# | Cbb                 | 關聯連接詞         |
# | D                   | 副詞               |
# | Da                  | 數量副詞           |
# | Dfa                 | 動詞前程度副詞     |
# | Dfb                 | 動詞後程度副詞     |
# | Di                  | 時態標記           |
# | Dk                  | 句副詞             |
# | DM                  | 定量式             |
# | I                   | 感嘆詞             |
# | Na                  | 普通名詞           |
# | Nb                  | 專有名詞           |
# | Nc                  | 地方詞             |
# | Ncd                 | 位置詞             |
# | Nd                  | 時間詞             |
# | Nep                 | 指代定詞           |
# | Neqa                | 數量定詞           |
# | Neqb                | 後置數量定詞       |
# | Nes                 | 特指定詞           |
# | Neu                 | 數詞定詞           |
# | Nf                  | 量詞               |
# | Ng                  | 後置詞             |
# | Nh                  | 代名詞             |
# | Nv                  | 名物化動詞         |
# | P                   | 介詞               |
# | T                   | 語助詞             |
# | VA                  | 動作不及物動詞     |
# | VAC                 | 動作使動動詞       |
# | VB                  | 動作類及物動詞     |
# | VC                  | 動作及物動詞       |
# | VCL                 | 動作接地方賓語動詞 |
# | VD                  | 雙賓動詞           |
# | VF                  | 動作謂賓動詞       |
# | VE                  | 動作句賓動詞       |
# | VG                  | 分類動詞           |
# | VH                  | 狀態不及物動詞     |
# | VHC                 | 狀態使動動詞       |
# | VI                  | 狀態類及物動詞     |
# | VJ                  | 狀態及物動詞       |
# | VK                  | 狀態句賓動詞       |
# | VL                  | 狀態謂賓動詞       |
# | V_2                 | 有                 |
# |                     |                    |
# | DE                  | 的之得地           |
# | SHI                 | 是                 |
# | FW                  | 外文               |
# |                     |                    |
# | COLONCATEGORY       | 冒號               |
# | COMMACATEGORY       | 逗號               |
# | DASHCATEGORY        | 破折號             |
# | DOTCATEGORY         | 點號               |
# | ETCCATEGORY         | 刪節號             |
# | EXCLAMATIONCATEGORY | 驚嘆號             |
# | PARENTHESISCATEGORY | 括號               |
# | PAUSECATEGORY       | 頓號               |
# | PERIODCATEGORY      | 句號               |
# | QUESTIONCATEGORY    | 問號               |
# | SEMICOLONCATEGORY   | 分號               |
# | SPCHANGECATEGORY    | 雙直線             |
# | WHITESPACE          | 空白               |

# %%
def get_bow_vector_with_selection(pairs, word2index):
    # 根據以上列舉出來的文字以及詞性表，請列出想要排除的詞性
    # YOUR CODE HERE
    excluded_flags = [   
        'WHITESPACE','SPCHANGECATEGORY','SEMICOLONCATEGORY','QUESTIONCATEGORY','PERIODCATEGORY','PAUSECATEGORY',
        'PARENTHESISCATEGORY','EXCLAMATIONCATEGORY','ETCCATEGORY','DOTCATEGORY','DASHCATEGORY','COMMACATEGORY','COLONCATEGORY',
        'SHI','DE','V_2','T','P','Nh','Ng','Nf','Nd','Neu','Nes','Neqb','Neqa','Nep','I','D','Di','Dk','DM','Cbb','Cba','Cab','Caa'
    ]
    # END YOUR CODE
    vector = np.zeros(len(word2index))
    for word, pos in pairs:
        if word in word2index and pos not in excluded_flags:
            vector[word2index[word]] += 1
    return vector

# %% [markdown]
# # Cosine Similarity

# %%
from numpy import linalg as la
def cosine_similarity(bow1, bow2):
    # YOUR CODE HERE
    similarity = np.dot(bow1,bow2) / (la.norm(bow1) * la.norm(bow2))
    # END YOUR CODE
    return similarity

# %%
bow1 = get_bow_vector(train_title_cuts[100], word2index)
bow2 = get_bow_vector(train_title_cuts[130], word2index)
cosine_similarity(bow1, bow2)
# Out:
# 0.08703882797784893

# %%
train_title_cuts[100]
# Out:
# [('山東', 'Nc'),
#  ('魯能', 'Nb'),
#  ('有沒有', 'D'),
#  ('可能', 'D'),
#  ('拿到', 'VC'),
#  ('今年', 'Nd'),
#  ('的', 'DE'),
#  ('中', 'A'),
#  ('超', 'A'),
#  ('冠軍', 'Na'),
#  ('？', 'QUESTIONCATEGORY')]

# %%
train_title_cuts[130]
# Out:
# [('NBA', 'Nb'),
#  ('和', 'Caa'),
#  ('CBA', 'FW'),
#  ('差距', 'Na'),
#  ('在', 'P'),
#  ('哪裡', 'Ncd'),
#  ('？', 'QUESTIONCATEGORY'),
#  ('6', 'Neu'),
#  ('張', 'Nf'),
#  ('圖', 'VF'),
#  ('一目瞭然', 'VH'),
#  ('！', 'EXCLAMATIONCATEGORY')]

# %% [markdown]
# # Group mean vector

# %%
group_vectors = {news_class: [] for news_class in all_news_class}
for index, pairs in sorted(train_title_cuts.items()):
    vector = get_bow_vector_with_selection(pairs, word2index)
    news_class = train_classes[index]
    group_vectors[news_class].append(vector)

group_mean_vector = {}
for news_class, vectors in group_vectors.items():
    group_mean_vector[news_class] = np.mean(vectors, axis=0)
group_mean_vector
# Out:
# {'體育': array([0.04      , 0.00333333, 0.        , ..., 0.        , 0.        ,
#         0.        ]),
#  '財經': array([0., 0., 0., ..., 0., 0., 0.]),
#  '科技': array([0., 0., 0., ..., 0., 0., 0.]),
#  '旅遊': array([0., 0., 0., ..., 0., 0., 0.]),
#  '農業': array([0., 0., 0., ..., 0., 0., 0.]),
#  '遊戲': array([0.        , 0.        , 0.        , ..., 0.00333333, 0.00333333,
#         0.00333333])}

# %% [markdown]
# # Group mean vector: 測試

# %%
classification = {news_class: [] for news_class in all_news_class}
for index, pairs in sorted(test_title_cuts.items()):
    vector = get_bow_vector_with_selection(pairs, word2index)
    if np.sum(np.square(vector)) == 0:
        continue

    max_val = -2.0
    max_class = None
    for news_class, ref_vector in group_mean_vector.items():
        val = cosine_similarity(ref_vector, vector)
        if val > max_val:
            max_class = news_class
            max_val = val

    classification[max_class].append(index)

# %%
from collections import Counter

for group, ids in classification.items():
    counter = Counter([test_classes[id] for id in ids])
    print('predict', group, ': ', counter)
# Out:
# predict 體育 :  Counter({'體育': 85, '遊戲': 8, '科技': 5, '農業': 4, '財經': 2, '旅遊': 2})
# predict 財經 :  Counter({'財經': 73, '科技': 20, '農業': 7, '旅遊': 3, '遊戲': 2, '體育': 1})
# predict 科技 :  Counter({'科技': 64, '財經': 15, '體育': 4, '旅遊': 4, '農業': 4, '遊戲': 2})
# predict 旅遊 :  Counter({'旅遊': 78, '農業': 8, '體育': 3, '財經': 2, '科技': 1, '遊戲': 1})
# predict 農業 :  Counter({'農業': 70, '旅遊': 8, '科技': 6, '財經': 5, '遊戲': 3})
# predict 遊戲 :  Counter({'遊戲': 84, '體育': 6, '旅遊': 4, '科技': 3, '農業': 3, '財經': 1})
