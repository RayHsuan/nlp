# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
import pandas as pd
import nltk
#nltk.download()
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %% [markdown]
# ### 從文本中取出所有單字

# %%
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.word_tokenize(sentence)
    for word in tokenized_sentence:
        whole_words.append(word)

# %% [markdown]
# ### 移除重複單字

# %%
whole_words = set(whole_words)
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2351個單字

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    word_index[word] = n
    index_word[n] = word
    n+=1

# %%
word_index
# Out:
# {'sample': 0,
#  'Indian': 1,
#  'baklava': 2,
#  'WORST': 3,
#  'another': 4,
#  'meatballs': 5,
#  'tapas': 6,
#  'entrees': 7,
#  'Flower': 8,
#  'warnings': 9,
#  'Furthermore': 10,
#  'Kind': 11,
#  'Loved': 12,
#  'Service-check': 13,
#  'Hawaiian': 14,
#  'Nice': 15,
#  'inviting': 16,
#  'living': 17,
#  'cause': 18,
#  'Classy/warm': 19,
#  'golden-crispy': 20,
#  'Friend': 21,
#  'opportunity': 22,
#  'known': 23,
#  'pancakes': 24,
#  'solidify': 25,
#  'refried': 26,
#  'tasted': 27,
#  'expectations': 28,
#  'slow': 29,
#  'disappoint': 30,
#  'bartender': 31,
#  ',': 32,
#  'pepper': 33,
#  'MUST': 34,
#  'to-go': 35,
#  'dealing': 36,
#  'FORWARD': 37,
#  'mall': 38,
#  'Nargile': 39,
#  'cheated': 40,
#  'small': 41,
#  'green': 42,
#  'night': 43,
#  'unwrapped': 44,
#  'THAT': 45,
#  'calligraphy': 46,
#  'luck': 47,
#  'spends': 48,
#  'NASTY': 49,
#  'pita': 50,
#  'rushed': 51,
#  'ventilation': 52,
#  'beans': 53,
#  'ethic': 54,
#  'tasteless': 55,
#  'should': 56,
#  'Bussell': 57,
#  'attention': 58,
#  'actual': 59,
#  'STALE': 60,
#  'bread': 61,
#  'Probably': 62,
#  'bloddy': 63,
#  'Tigerlilly': 64,
#  'tiramisu': 65,
#  'as': 66,
#  'min': 67,
#  'hours': 68,
#  'will': 69,
#  'someone': 70,
#  'ones': 71,
#  'brought': 72,
#  'tastings': 73,
#  'VERY': 74,
#  'whether': 75,
#  'bank': 76,
#  'teeth': 77,
#  'mouthful': 78,
#  'his': 79,
#  'seating': 80,
#  'excellent': 81,
#  'mozzarella': 82,
#  'Sunday': 83,
#  'visit': 84,
#  'homemade': 85,
#  'in': 86,
#  'piece': 87,
#  'fairly': 88,
#  'fabulous': 89,
#  'once': 90,
#  'old': 91,
#  'And': 92,
#  'Outstanding': 93,
#  '2007': 94,
#  'missed': 95,
#  'figured': 96,
#  'limited': 97,
#  'indoor': 98,
#  '&': 99,
#  'hottest': 100,
#  'godfathers': 101,
#  'parents': 102,
#  'voted': 103,
#  'app': 104,
#  '``': 105,
#  'FLAVOR': 106,
#  'appetizers': 107,
#  'block': 108,
#  '6': 109,
#  'piano': 110,
#  'belly': 111,
#  'quantity': 112,
#  'bites': 113,
#  'dishes': 114,
#  'Hopefully': 115,
#  'rest': 116,
#  'CONCLUSION': 117,
#  'beyond': 118,
#  'assure': 119,
#  'huevos': 120,
#  'Nothing': 121,
#  'dipping': 122,
#  'appetizer': 123,
#  'melted': 124,
#  'put': 125,
#  'duo': 126,
#  '1979': 127,
#  'cost': 128,
#  'receives': 129,
#  'worse': 130,
#  'Total': 131,
#  'T.': 132,
#  'impressed': 133,
#  'Delight': 134,
#  'non-fancy': 135,
#  'disgust': 136,
#  'spice': 137,
#  'gratuity': 138,
#  'delivery': 139,
#  'flavourful': 140,
#  'gone': 141,
#  'pancake': 142,
#  'serving': 143,
#  '4.00': 144,
#  'wontons': 145,
#  'black': 146,
#  'cranberry': 147,
#  'hospitality': 148,
#  'from': 149,
#  'die': 150,
#  'biscuits': 151,
#  'thirty': 152,
#  'hated': 153,
#  'spots': 154,
#  'quit': 155,
#  'Breeze': 156,
#  'included': 157,
#  'been-stepped-in-and-tracked-everywhere': 158,
#  'Otto': 159,
#  'diverse': 160,
#  'So': 161,
#  'vibe': 162,
#  'gross': 163,
#  'rowdy': 164,
#  'warmer': 165,
#  'wildly': 166,
#  'angry': 167,
#  'Great': 168,
#  'callings': 169,
#  'give': 170,
#  'friend': 171,
#  '35': 172,
#  'crust': 173,
#  'Large': 174,
#  'website': 175,
#  'hot': 176,
#  'over-whelm': 177,
#  'When': 178,
#  'off': 179,
#  'supposed': 180,
#  'cook': 181,
#  'i': 182,
#  'HOUR': 183,
#  'Disappointed': 184,
#  'fat': 185,
#  'M': 186,
#  'handled': 187,
#  'healthy': 188,
#  'amount': 189,
#  'our': 190,
#  'cheese': 191,
#  'non-customer': 192,
#  'Del': 193,
#  'Each': 194,
#  'puree': 195,
#  'strip': 196,
#  'egg': 197,
#  'LOVED': 198,
#  'What': 199,
#  'my': 200,
#  'complain': 201,
#  'descriptions': 202,
#  'Mandalay': 203,
#  'Sun': 204,
#  '3': 205,
#  'here': 206,
#  'unique': 207,
#  'order': 208,
#  'extremely': 209,
#  'guess': 210,
#  'bartenders': 211,
#  'Prices': 212,
#  'boys': 213,
#  'decide': 214,
#  'anticipated': 215,
#  '30': 216,
#  'although': 217,
#  'like': 218,
#  'close': 219,
#  'genuinely': 220,
#  'ohhh': 221,
#  'strawberry': 222,
#  'between': 223,
#  '?': 224,
#  'thumbs': 225,
#  'Based': 226,
#  'WHAT': 227,
#  'summer': 228,
#  'sub-par': 229,
#  'rubber': 230,
#  'If': 231,
#  'wife': 232,
#  'despicable': 233,
#  'everything': 234,
#  'ourselves': 235,
#  'wants': 236,
#  'public': 237,
#  'noodles': 238,
#  'fucking': 239,
#  'Join': 240,
#  'attitudes': 241,
#  'signs': 242,
#  'handmade': 243,
#  'chickens': 244,
#  'bring': 245,
#  'In': 246,
#  'Boy': 247,
#  'box': 248,
#  'muffin': 249,
#  'me': 250,
#  'sugary': 251,
#  'Gave': 252,
#  'amazing': 253,
#  'deal': 254,
#  'bodes': 255,
#  'mom': 256,
#  'dog': 257,
#  'mac': 258,
#  'disapppointment': 259,
#  '1/2': 260,
#  'anyone': 261,
#  'original': 262,
#  'discount': 263,
#  'THIS': 264,
#  'classic': 265,
#  'touched': 266,
#  'are': 267,
#  'binge': 268,
#  'enough': 269,
#  'effort': 270,
#  'PERFECT': 271,
#  'pretty': 272,
#  'Not': 273,
#  '23': 274,
#  'uploaded': 275,
#  'nearly': 276,
#  'TOLD': 277,
#  'palate': 278,
#  'combination': 279,
#  'dedicated': 280,
#  'words': 281,
#  'nachos': 282,
#  '-Drinks': 283,
#  'He': 284,
#  'Rice': 285,
#  'salad': 286,
#  'space': 287,
#  'topic': 288,
#  'seen': 289,
#  'Disappointing': 290,
#  'Hunan': 291,
#  'wide': 292,
#  '20': 293,
#  'Ironman': 294,
#  'Khao': 295,
#  'thin': 296,
#  'rude': 297,
#  'honestly': 298,
#  'sals': 299,
#  'rapidly': 300,
#  'average': 301,
#  'Hiro': 302,
#  'reviews': 303,
#  'walls': 304,
#  'otherwise': 305,
#  'short': 306,
#  'gold': 307,
#  'spicier': 308,
#  'marrow': 309,
#  'opened': 310,
#  'Ryan': 311,
#  '100': 312,
#  'lunch': 313,
#  'HANDS': 314,
#  'suck': 315,
#  'salads': 316,
#  'ambiance': 317,
#  'perpared': 318,
#  'drunk': 319,
#  'portions': 320,
#  'concern': 321,
#  'batter': 322,
#  'gas': 323,
#  'Sadly': 324,
#  'overall': 325,
#  'spinach': 326,
#  'rich': 327,
#  'daily': 328,
#  'sewer': 329,
#  'cocktails': 330,
#  'finger': 331,
#  'spices': 332,
#  'desserts': 333,
#  'accordingly': 334,
#  'pumpkin': 335,
#  'unless': 336,
#  'liked': 337,
#  'Bisque': 338,
#  'Coffee': 339,
#  'mussels': 340,
#  'lightly': 341,
#  'Needless': 342,
#  'brings': 343,
#  'violinists': 344,
#  'flat': 345,
#  'pissd': 346,
#  'thats': 347,
#  'Coming': 348,
#  'satisfied': 349,
#  'sore': 350,
#  'bunch': 351,
#  'cover': 352,
#  'skimp': 353,
#  'Crust': 354,
#  'provides': 355,
#  'cuisine': 356,
#  'Pizza': 357,
#  'IT': 358,
#  'refreshing': 359,
#  'both': 360,
#  'Those': 361,
#  'wait': 362,
#  'sucks': 363,
#  'bakery': 364,
#  'struggle': 365,
#  'decided': 366,
#  'potato': 367,
#  'bad': 368,
#  'unfortunately': 369,
#  'Dos': 370,
#  'recall': 371,
#  'sorely': 372,
#  'Thoroughly': 373,
#  'company': 374,
#  'somehow': 375,
#  'rating': 376,
#  'succulent': 377,
#  'memory': 378,
#  'slices': 379,
#  'being': 380,
#  'each': 381,
#  'leave': 382,
#  'burgers': 383,
#  'for': 384,
#  'back': 385,
#  'condiment': 386,
#  'feel': 387,
#  'spring': 388,
#  'blown': 389,
#  'spotty': 390,
#  'uninspired': 391,
#  'Much': 392,
#  'convenient': 393,
#  'pulled': 394,
#  '40min': 395,
#  'ingredients': 396,
#  'entire': 397,
#  'redeeming': 398,
#  'flat-lined': 399,
#  'menus': 400,
#  'feeling': 401,
#  'pastry': 402,
#  'seafood': 403,
#  'sub': 404,
#  'judge': 405,
#  'high': 406,
#  'sure': 407,
#  'towards': 408,
#  'outstanding': 409,
#  'seasoned': 410,
#  'we': 411,
#  'bowl': 412,
#  'prepare': 413,
#  'consistent': 414,
#  'carpaccio': 415,
#  'Def': 416,
#  'continue': 417,
#  'airline': 418,
#  'food/service': 419,
#  '12': 420,
#  'services': 421,
#  'requested': 422,
#  'absolute': 423,
#  'HAD': 424,
#  'dusted': 425,
#  'reheated': 426,
#  'maintaining': 427,
#  'next': 428,
#  'wow': 429,
#  'money': 430,
#  'doubt': 431,
#  'months': 432,
#  'with': 433,
#  'waited': 434,
#  'indicate': 435,
#  'wayyy': 436,
#  'generous': 437,
#  'Camelback': 438,
#  'OVERPRICED': 439,
#  'then': 440,
#  'reasonable': 441,
#  'hits': 442,
#  'prefer': 443,
#  'so': 444,
#  'Pretty': 445,
#  'reduction': 446,
#  'beer': 447,
#  '2': 448,
#  'dinners': 449,
#  'Have': 450,
#  'yet': 451,
#  'number': 452,
#  'where': 453,
#  'Paradise': 454,
#  'brisket': 455,
#  'service': 456,
#  'mediocre': 457,
#  'zero': 458,
#  'sugar': 459,
#  'mood': 460,
#  'received': 461,
#  'plate': 462,
#  'Which': 463,
#  'prices': 464,
#  '....': 465,
#  'Soggy': 466,
#  'wagyu': 467,
#  'SHOULD': 468,
#  'They': 469,
#  'street': 470,
#  'officially': 471,
#  'Maria': 472,
#  'Risotto': 473,
#  '(': 474,
#  'something': 475,
#  'their': 476,
#  'BARGAIN': 477,
#  'relationship': 478,
#  'mortified': 479,
#  'All': 480,
#  'pace': 481,
#  'judging': 482,
#  'horrible': 483,
#  'cashier': 484,
#  'stood': 485,
#  'yukon': 486,
#  'area': 487,
#  'decent': 488,
#  'meh': 489,
#  'her': 490,
#  'BITCHES': 491,
#  'sauces': 492,
#  'prepared': 493,
#  'hearts': 494,
#  'Ramsey': 495,
#  'would': 496,
#  'By': 497,
#  'outshining': 498,
#  'your': 499,
#  'Big': 500,
#  'Fridays': 501,
#  'ago': 502,
#  'talking': 503,
#  'this': 504,
#  'world': 505,
#  '70+': 506,
#  'presentation': 507,
#  'Caesar': 508,
#  'Seriously': 509,
#  'glass': 510,
#  'milk': 511,
#  'Honeslty': 512,
#  'Kids': 513,
#  'ca': 514,
#  'boyfriend': 515,
#  'beers': 516,
#  'fav': 517,
#  'customize': 518,
#  'thinly': 519,
#  'jalapeno': 520,
#  'steaks': 521,
#  'banana': 522,
#  'review': 523,
#  'movies': 524,
#  'coziness': 525,
#  'them': 526,
#  'meal': 527,
#  'offered': 528,
#  'claimed': 529,
#  'management': 530,
#  'Server': 531,
#  'greasy': 532,
#  'lighting': 533,
#  'caught': 534,
#  'theft': 535,
#  'We': 536,
#  'completely': 537,
#  'fireball': 538,
#  'combo': 539,
#  'andddd': 540,
#  'apologize': 541,
#  'hands-down': 542,
#  'fondue': 543,
#  'sunglasses': 544,
#  'pricey': 545,
#  'sucker': 546,
#  'inch': 547,
#  'itself': 548,
#  'Joey': 549,
#  'famous': 550,
#  'fan': 551,
#  'High-quality': 552,
#  'glad': 553,
#  'parties': 554,
#  'You': 555,
#  'Place': 556,
#  'gristle': 557,
#  'buffets': 558,
#  'operation': 559,
#  'him': 560,
#  'Stars': 561,
#  'profiterole': 562,
#  'dirt': 563,
#  'crowd': 564,
#  'speedy': 565,
#  'very': 566,
#  'worst': 567,
#  'offers': 568,
#  'letdown': 569,
#  'satifying': 570,
#  '17': 571,
#  'neither': 572,
#  'shoe': 573,
#  'southwest': 574,
#  'Vegas': 575,
#  'highlight': 576,
#  'power': 577,
#  'girlfriend': 578,
#  'specials': 579,
#  'Subway': 580,
#  'paper': 581,
#  'six': 582,
#  ')': 583,
#  '30s': 584,
#  'charming': 585,
#  'do': 586,
#  'its': 587,
#  'caring': 588,
#  'TV': 589,
#  'pizzas': 590,
#  'enjoy': 591,
#  'unhealthy': 592,
#  'occasions': 593,
#  'weekend': 594,
#  'favorite': 595,
#  'Mom': 596,
#  'Of': 597,
#  'middle': 598,
#  'house': 599,
#  'found': 600,
#  'tartare': 601,
#  'thick': 602,
#  'contain': 603,
#  'plus': 604,
#  'guest': 605,
#  'verge': 606,
#  'at': 607,
#  'seal': 608,
#  'missing': 609,
#  'different': 610,
#  'added': 611,
#  'they': 612,
#  'plethora': 613,
#  'son': 614,
#  'bug': 615,
#  'needs': 616,
#  'funny': 617,
#  'sit-down': 618,
#  'everyone': 619,
#  'why': 620,
#  'finally': 621,
#  'used': 622,
#  'most': 623,
#  'of': 624,
#  'A': 625,
#  'Thus': 626,
#  'authentic': 627,
#  'Mmmm': 628,
#  'chai': 629,
#  'fair': 630,
#  'interesting': 631,
#  'inflate': 632,
#  'love': 633,
#  'hope': 634,
#  'Cotta': 635,
#  'Although': 636,
#  'first': 637,
#  '8': 638,
#  'tater': 639,
#  'owned': 640,
#  'NONE': 641,
#  'guests': 642,
#  'fries': 643,
#  'Once': 644,
#  'joint': 645,
#  'setting': 646,
#  'alone': 647,
#  'lost': 648,
#  'dripping': 649,
#  'drastically': 650,
#  'smooth': 651,
#  'waiter': 652,
#  'taco': 653,
#  'mixed': 654,
#  'awkwardly': 655,
#  'Bacon': 656,
#  'customer': 657,
#  'HAPPENED': 658,
#  'drawing': 659,
#  'pneumatic': 660,
#  'Im': 661,
#  'THE': 662,
#  'having': 663,
#  'charge': 664,
#  'lighter': 665,
#  'pay': 666,
#  'work': 667,
#  'went': 668,
#  'crazy': 669,
#  'be': 670,
#  'tiny': 671,
#  'My': 672,
#  'breaks': 673,
#  'staying': 674,
#  'wash': 675,
#  'strange': 676,
#  'Today': 677,
#  'bone': 678,
#  'rare': 679,
#  'sexy': 680,
#  'Steiners': 681,
#  'shirt': 682,
#  'Heart': 683,
#  'Panna': 684,
#  'poor': 685,
#  'crêpe': 686,
#  'NOT': 687,
#  'fry': 688,
#  'soooooo': 689,
#  'cart': 690,
#  'petty': 691,
#  'military': 692,
#  '40': 693,
#  'welcome': 694,
#  'favor': 695,
#  'covered': 696,
#  'bathrooms': 697,
#  'set': 698,
#  'array': 699,
#  'Frozen': 700,
#  'grill': 701,
#  'Caballero': 702,
#  'STEP': 703,
#  'read': 704,
#  'awesome': 705,
#  'sound': 706,
#  'say': 707,
#  'maybe': 708,
#  'Smashburger': 709,
#  'consider': 710,
#  'foot': 711,
#  'approval': 712,
#  'tots': 713,
#  'selection': 714,
#  'caterpillar': 715,
#  'Are': 716,
#  'TIME': 717,
#  'shoots': 718,
#  'Lox': 719,
#  'via': 720,
#  'pile': 721,
#  'nude': 722,
#  'peanut': 723,
#  'said': 724,
#  'bye': 725,
#  'lot': 726,
#  'neighborhood': 727,
#  'corn': 728,
#  'told': 729,
#  'excuse': 730,
#  'grow': 731,
#  'Jeff': 732,
#  'picture': 733,
#  'forth': 734,
#  'happened': 735,
#  'Nobu': 736,
#  'realized': 737,
#  'cheeseburger': 738,
#  'plain': 739,
#  'bathroom': 740,
#  'basically': 741,
#  'Steak': 742,
#  'white': 743,
#  'Gold': 744,
#  'unprofessional': 745,
#  'seated': 746,
#  'eat': 747,
#  'eel': 748,
#  'Café': 749,
#  'dreamed': 750,
#  'almost': 751,
#  'mmmm': 752,
#  'disgraceful': 753,
#  'been': 754,
#  'Generous': 755,
#  'AYCE': 756,
#  'delicate': 757,
#  'revisiting': 758,
#  'wish': 759,
#  'juice': 760,
#  'Owner': 761,
#  'Service': 762,
#  'bruschetta': 763,
#  'bigger': 764,
#  'vegetables': 765,
#  'ok': 766,
#  'tummy': 767,
#  'croutons': 768,
#  'folks': 769,
#  'friendly': 770,
#  'rings': 771,
#  'fiancé': 772,
#  'dollars': 773,
#  'generic': 774,
#  'she': 775,
#  'SCREAMS': 776,
#  'Dylan': 777,
#  'evening': 778,
#  'acknowledged': 779,
#  'capers': 780,
#  'person': 781,
#  'Cibo': 782,
#  'call': 783,
#  'driest': 784,
#  'AVOID': 785,
#  'double': 786,
#  'rate': 787,
#  'send': 788,
#  'strings': 789,
#  'bits': 790,
#  'reading': 791,
#  'Denny': 792,
#  'coupons': 793,
#  'Come': 794,
#  'degree': 795,
#  'waitresses': 796,
#  'touch': 797,
#  '/hand': 798,
#  'over-hip': 799,
#  '11.99': 800,
#  'held': 801,
#  'end': 802,
#  'subpar': 803,
#  'gooodd': 804,
#  'polite': 805,
#  'stuffed': 806,
#  'madhouse': 807,
#  'kept': 808,
#  'edible': 809,
#  'color': 810,
#  'ate': 811,
#  'chips': 812,
#  'privileged': 813,
#  'else': 814,
#  'Could': 815,
#  'IN': 816,
#  'Try': 817,
#  'decorated': 818,
#  'car': 819,
#  'inside': 820,
#  'hummus': 821,
#  'does': 822,
#  'contained': 823,
#  'below': 824,
#  'bite': 825,
#  'quick': 826,
#  'EVER': 827,
#  'arriving': 828,
#  'truffle': 829,
#  'Casino': 830,
#  'industry': 831,
#  'dressing': 832,
#  'hankering': 833,
#  'poorly': 834,
#  'Cant': 835,
#  'decor': 836,
#  'employees': 837,
#  'Do': 838,
#  'martini': 839,
#  'owner/chef': 840,
#  'pleasant': 841,
#  'unexperienced': 842,
#  'mile': 843,
#  'ratio': 844,
#  'mouth': 845,
#  'roasted': 846,
#  '...': 847,
#  'or': 848,
#  'delightful': 849,
#  'cavier': 850,
#  'lawyers': 851,
#  'especially': 852,
#  'coconut': 853,
#  'also': 854,
#  'daughter': 855,
#  'mayo': 856,
#  'rotating': 857,
#  'ended': 858,
#  'cooked': 859,
#  'Went': 860,
#  'steak': 861,
#  'place': 862,
#  'Voodoo': 863,
#  'BARE': 864,
#  'flirting': 865,
#  'great': 866,
#  'overwhelmed': 867,
#  'stale': 868,
#  'Chinese': 869,
#  'super': 870,
#  'Burrittos': 871,
#  'menu': 872,
#  'frozen': 873,
#  'eggs': 874,
#  'MGM': 875,
#  'pasta': 876,
#  'make': 877,
#  'APPETIZERS': 878,
#  'profound': 879,
#  'Mary': 880,
#  'real': 881,
#  'life': 882,
#  'instead': 883,
#  'Please': 884,
#  'seasonal': 885,
#  'full': 886,
#  '$': 887,
#  'husband': 888,
#  'medium': 889,
#  'reasons': 890,
#  'Han': 891,
#  'powdered': 892,
#  'For': 893,
#  'screwed': 894,
#  'new': 895,
#  'Eew': 896,
#  'grocery': 897,
#  'Go': 898,
#  'pats': 899,
#  'loyal': 900,
#  'raspberry': 901,
#  'First': 902,
#  'none': 903,
#  'than': 904,
#  'nasty': 905,
#  'themselves': 906,
#  'patty': 907,
#  'batch': 908,
#  'hopes': 909,
#  'After': 910,
#  'either': 911,
#  'sat': 912,
#  'since': 913,
#  'truly': 914,
#  'group': 915,
#  'vomited': 916,
#  'come': 917,
#  'years': 918,
#  'refused': 919,
#  'dont': 920,
#  'NO': 921,
#  'Sooooo': 922,
#  'may': 923,
#  'job': 924,
#  'Strike': 925,
#  'tolerance': 926,
#  'winner': 927,
#  'rolls': 928,
#  '90': 929,
#  'appealing': 930,
#  'opposed': 931,
#  'hair': 932,
#  'tender': 933,
#  'meet': 934,
#  'dessert': 935,
#  'apart': 936,
#  'suggestions': 937,
#  'Back': 938,
#  'lacked': 939,
#  'biscuit': 940,
#  'date': 941,
#  'trying': 942,
#  '-My': 943,
#  'One': 944,
#  'Baba': 945,
#  'fact': 946,
#  'by': 947,
#  'AN': 948,
#  'douchey': 949,
#  'eggplant': 950,
#  'simple': 951,
#  'fella': 952,
#  'An': 953,
#  'baby': 954,
#  'Perhaps': 955,
#  '.': 956,
#  'oh': 957,
#  'haunt': 958,
#  'waiting': 959,
#  'greeted': 960,
#  'happier': 961,
#  'somewhat': 962,
#  'toro': 963,
#  'grandmother': 964,
#  'imaginative': 965,
#  'smells': 966,
#  'music': 967,
#  'done': 968,
#  'letting': 969,
#  'during': 970,
#  'outside': 971,
#  'guy': 972,
#  'OK': 973,
#  'located': 974,
#  'cheap': 975,
#  'were': 976,
#  'rib': 977,
#  'Hot': 978,
#  'cut': 979,
#  'cheesecurds': 980,
#  'compliments': 981,
#  'ala': 982,
#  'Sauce': 983,
#  'disappointing': 984,
#  'deep': 985,
#  'proven': 986,
#  'May': 987,
#  'Aria': 988,
#  'drinks': 989,
#  'couple': 990,
#  'exquisite': 991,
#  'greatest': 992,
#  'moz': 993,
#  'hit': 994,
#  'under': 995,
#  'opinion': 996,
#  'stir': 997,
#  'hooked': 998,
#  'imagine': 999,
#  ...}

# %%
index_word
# Out:
# {0: 'sample',
#  1: 'Indian',
#  2: 'baklava',
#  3: 'WORST',
#  4: 'another',
#  5: 'meatballs',
#  6: 'tapas',
#  7: 'entrees',
#  8: 'Flower',
#  9: 'warnings',
#  10: 'Furthermore',
#  11: 'Kind',
#  12: 'Loved',
#  13: 'Service-check',
#  14: 'Hawaiian',
#  15: 'Nice',
#  16: 'inviting',
#  17: 'living',
#  18: 'cause',
#  19: 'Classy/warm',
#  20: 'golden-crispy',
#  21: 'Friend',
#  22: 'opportunity',
#  23: 'known',
#  24: 'pancakes',
#  25: 'solidify',
#  26: 'refried',
#  27: 'tasted',
#  28: 'expectations',
#  29: 'slow',
#  30: 'disappoint',
#  31: 'bartender',
#  32: ',',
#  33: 'pepper',
#  34: 'MUST',
#  35: 'to-go',
#  36: 'dealing',
#  37: 'FORWARD',
#  38: 'mall',
#  39: 'Nargile',
#  40: 'cheated',
#  41: 'small',
#  42: 'green',
#  43: 'night',
#  44: 'unwrapped',
#  45: 'THAT',
#  46: 'calligraphy',
#  47: 'luck',
#  48: 'spends',
#  49: 'NASTY',
#  50: 'pita',
#  51: 'rushed',
#  52: 'ventilation',
#  53: 'beans',
#  54: 'ethic',
#  55: 'tasteless',
#  56: 'should',
#  57: 'Bussell',
#  58: 'attention',
#  59: 'actual',
#  60: 'STALE',
#  61: 'bread',
#  62: 'Probably',
#  63: 'bloddy',
#  64: 'Tigerlilly',
#  65: 'tiramisu',
#  66: 'as',
#  67: 'min',
#  68: 'hours',
#  69: 'will',
#  70: 'someone',
#  71: 'ones',
#  72: 'brought',
#  73: 'tastings',
#  74: 'VERY',
#  75: 'whether',
#  76: 'bank',
#  77: 'teeth',
#  78: 'mouthful',
#  79: 'his',
#  80: 'seating',
#  81: 'excellent',
#  82: 'mozzarella',
#  83: 'Sunday',
#  84: 'visit',
#  85: 'homemade',
#  86: 'in',
#  87: 'piece',
#  88: 'fairly',
#  89: 'fabulous',
#  90: 'once',
#  91: 'old',
#  92: 'And',
#  93: 'Outstanding',
#  94: '2007',
#  95: 'missed',
#  96: 'figured',
#  97: 'limited',
#  98: 'indoor',
#  99: '&',
#  100: 'hottest',
#  101: 'godfathers',
#  102: 'parents',
#  103: 'voted',
#  104: 'app',
#  105: '``',
#  106: 'FLAVOR',
#  107: 'appetizers',
#  108: 'block',
#  109: '6',
#  110: 'piano',
#  111: 'belly',
#  112: 'quantity',
#  113: 'bites',
#  114: 'dishes',
#  115: 'Hopefully',
#  116: 'rest',
#  117: 'CONCLUSION',
#  118: 'beyond',
#  119: 'assure',
#  120: 'huevos',
#  121: 'Nothing',
#  122: 'dipping',
#  123: 'appetizer',
#  124: 'melted',
#  125: 'put',
#  126: 'duo',
#  127: '1979',
#  128: 'cost',
#  129: 'receives',
#  130: 'worse',
#  131: 'Total',
#  132: 'T.',
#  133: 'impressed',
#  134: 'Delight',
#  135: 'non-fancy',
#  136: 'disgust',
#  137: 'spice',
#  138: 'gratuity',
#  139: 'delivery',
#  140: 'flavourful',
#  141: 'gone',
#  142: 'pancake',
#  143: 'serving',
#  144: '4.00',
#  145: 'wontons',
#  146: 'black',
#  147: 'cranberry',
#  148: 'hospitality',
#  149: 'from',
#  150: 'die',
#  151: 'biscuits',
#  152: 'thirty',
#  153: 'hated',
#  154: 'spots',
#  155: 'quit',
#  156: 'Breeze',
#  157: 'included',
#  158: 'been-stepped-in-and-tracked-everywhere',
#  159: 'Otto',
#  160: 'diverse',
#  161: 'So',
#  162: 'vibe',
#  163: 'gross',
#  164: 'rowdy',
#  165: 'warmer',
#  166: 'wildly',
#  167: 'angry',
#  168: 'Great',
#  169: 'callings',
#  170: 'give',
#  171: 'friend',
#  172: '35',
#  173: 'crust',
#  174: 'Large',
#  175: 'website',
#  176: 'hot',
#  177: 'over-whelm',
#  178: 'When',
#  179: 'off',
#  180: 'supposed',
#  181: 'cook',
#  182: 'i',
#  183: 'HOUR',
#  184: 'Disappointed',
#  185: 'fat',
#  186: 'M',
#  187: 'handled',
#  188: 'healthy',
#  189: 'amount',
#  190: 'our',
#  191: 'cheese',
#  192: 'non-customer',
#  193: 'Del',
#  194: 'Each',
#  195: 'puree',
#  196: 'strip',
#  197: 'egg',
#  198: 'LOVED',
#  199: 'What',
#  200: 'my',
#  201: 'complain',
#  202: 'descriptions',
#  203: 'Mandalay',
#  204: 'Sun',
#  205: '3',
#  206: 'here',
#  207: 'unique',
#  208: 'order',
#  209: 'extremely',
#  210: 'guess',
#  211: 'bartenders',
#  212: 'Prices',
#  213: 'boys',
#  214: 'decide',
#  215: 'anticipated',
#  216: '30',
#  217: 'although',
#  218: 'like',
#  219: 'close',
#  220: 'genuinely',
#  221: 'ohhh',
#  222: 'strawberry',
#  223: 'between',
#  224: '?',
#  225: 'thumbs',
#  226: 'Based',
#  227: 'WHAT',
#  228: 'summer',
#  229: 'sub-par',
#  230: 'rubber',
#  231: 'If',
#  232: 'wife',
#  233: 'despicable',
#  234: 'everything',
#  235: 'ourselves',
#  236: 'wants',
#  237: 'public',
#  238: 'noodles',
#  239: 'fucking',
#  240: 'Join',
#  241: 'attitudes',
#  242: 'signs',
#  243: 'handmade',
#  244: 'chickens',
#  245: 'bring',
#  246: 'In',
#  247: 'Boy',
#  248: 'box',
#  249: 'muffin',
#  250: 'me',
#  251: 'sugary',
#  252: 'Gave',
#  253: 'amazing',
#  254: 'deal',
#  255: 'bodes',
#  256: 'mom',
#  257: 'dog',
#  258: 'mac',
#  259: 'disapppointment',
#  260: '1/2',
#  261: 'anyone',
#  262: 'original',
#  263: 'discount',
#  264: 'THIS',
#  265: 'classic',
#  266: 'touched',
#  267: 'are',
#  268: 'binge',
#  269: 'enough',
#  270: 'effort',
#  271: 'PERFECT',
#  272: 'pretty',
#  273: 'Not',
#  274: '23',
#  275: 'uploaded',
#  276: 'nearly',
#  277: 'TOLD',
#  278: 'palate',
#  279: 'combination',
#  280: 'dedicated',
#  281: 'words',
#  282: 'nachos',
#  283: '-Drinks',
#  284: 'He',
#  285: 'Rice',
#  286: 'salad',
#  287: 'space',
#  288: 'topic',
#  289: 'seen',
#  290: 'Disappointing',
#  291: 'Hunan',
#  292: 'wide',
#  293: '20',
#  294: 'Ironman',
#  295: 'Khao',
#  296: 'thin',
#  297: 'rude',
#  298: 'honestly',
#  299: 'sals',
#  300: 'rapidly',
#  301: 'average',
#  302: 'Hiro',
#  303: 'reviews',
#  304: 'walls',
#  305: 'otherwise',
#  306: 'short',
#  307: 'gold',
#  308: 'spicier',
#  309: 'marrow',
#  310: 'opened',
#  311: 'Ryan',
#  312: '100',
#  313: 'lunch',
#  314: 'HANDS',
#  315: 'suck',
#  316: 'salads',
#  317: 'ambiance',
#  318: 'perpared',
#  319: 'drunk',
#  320: 'portions',
#  321: 'concern',
#  322: 'batter',
#  323: 'gas',
#  324: 'Sadly',
#  325: 'overall',
#  326: 'spinach',
#  327: 'rich',
#  328: 'daily',
#  329: 'sewer',
#  330: 'cocktails',
#  331: 'finger',
#  332: 'spices',
#  333: 'desserts',
#  334: 'accordingly',
#  335: 'pumpkin',
#  336: 'unless',
#  337: 'liked',
#  338: 'Bisque',
#  339: 'Coffee',
#  340: 'mussels',
#  341: 'lightly',
#  342: 'Needless',
#  343: 'brings',
#  344: 'violinists',
#  345: 'flat',
#  346: 'pissd',
#  347: 'thats',
#  348: 'Coming',
#  349: 'satisfied',
#  350: 'sore',
#  351: 'bunch',
#  352: 'cover',
#  353: 'skimp',
#  354: 'Crust',
#  355: 'provides',
#  356: 'cuisine',
#  357: 'Pizza',
#  358: 'IT',
#  359: 'refreshing',
#  360: 'both',
#  361: 'Those',
#  362: 'wait',
#  363: 'sucks',
#  364: 'bakery',
#  365: 'struggle',
#  366: 'decided',
#  367: 'potato',
#  368: 'bad',
#  369: 'unfortunately',
#  370: 'Dos',
#  371: 'recall',
#  372: 'sorely',
#  373: 'Thoroughly',
#  374: 'company',
#  375: 'somehow',
#  376: 'rating',
#  377: 'succulent',
#  378: 'memory',
#  379: 'slices',
#  380: 'being',
#  381: 'each',
#  382: 'leave',
#  383: 'burgers',
#  384: 'for',
#  385: 'back',
#  386: 'condiment',
#  387: 'feel',
#  388: 'spring',
#  389: 'blown',
#  390: 'spotty',
#  391: 'uninspired',
#  392: 'Much',
#  393: 'convenient',
#  394: 'pulled',
#  395: '40min',
#  396: 'ingredients',
#  397: 'entire',
#  398: 'redeeming',
#  399: 'flat-lined',
#  400: 'menus',
#  401: 'feeling',
#  402: 'pastry',
#  403: 'seafood',
#  404: 'sub',
#  405: 'judge',
#  406: 'high',
#  407: 'sure',
#  408: 'towards',
#  409: 'outstanding',
#  410: 'seasoned',
#  411: 'we',
#  412: 'bowl',
#  413: 'prepare',
#  414: 'consistent',
#  415: 'carpaccio',
#  416: 'Def',
#  417: 'continue',
#  418: 'airline',
#  419: 'food/service',
#  420: '12',
#  421: 'services',
#  422: 'requested',
#  423: 'absolute',
#  424: 'HAD',
#  425: 'dusted',
#  426: 'reheated',
#  427: 'maintaining',
#  428: 'next',
#  429: 'wow',
#  430: 'money',
#  431: 'doubt',
#  432: 'months',
#  433: 'with',
#  434: 'waited',
#  435: 'indicate',
#  436: 'wayyy',
#  437: 'generous',
#  438: 'Camelback',
#  439: 'OVERPRICED',
#  440: 'then',
#  441: 'reasonable',
#  442: 'hits',
#  443: 'prefer',
#  444: 'so',
#  445: 'Pretty',
#  446: 'reduction',
#  447: 'beer',
#  448: '2',
#  449: 'dinners',
#  450: 'Have',
#  451: 'yet',
#  452: 'number',
#  453: 'where',
#  454: 'Paradise',
#  455: 'brisket',
#  456: 'service',
#  457: 'mediocre',
#  458: 'zero',
#  459: 'sugar',
#  460: 'mood',
#  461: 'received',
#  462: 'plate',
#  463: 'Which',
#  464: 'prices',
#  465: '....',
#  466: 'Soggy',
#  467: 'wagyu',
#  468: 'SHOULD',
#  469: 'They',
#  470: 'street',
#  471: 'officially',
#  472: 'Maria',
#  473: 'Risotto',
#  474: '(',
#  475: 'something',
#  476: 'their',
#  477: 'BARGAIN',
#  478: 'relationship',
#  479: 'mortified',
#  480: 'All',
#  481: 'pace',
#  482: 'judging',
#  483: 'horrible',
#  484: 'cashier',
#  485: 'stood',
#  486: 'yukon',
#  487: 'area',
#  488: 'decent',
#  489: 'meh',
#  490: 'her',
#  491: 'BITCHES',
#  492: 'sauces',
#  493: 'prepared',
#  494: 'hearts',
#  495: 'Ramsey',
#  496: 'would',
#  497: 'By',
#  498: 'outshining',
#  499: 'your',
#  500: 'Big',
#  501: 'Fridays',
#  502: 'ago',
#  503: 'talking',
#  504: 'this',
#  505: 'world',
#  506: '70+',
#  507: 'presentation',
#  508: 'Caesar',
#  509: 'Seriously',
#  510: 'glass',
#  511: 'milk',
#  512: 'Honeslty',
#  513: 'Kids',
#  514: 'ca',
#  515: 'boyfriend',
#  516: 'beers',
#  517: 'fav',
#  518: 'customize',
#  519: 'thinly',
#  520: 'jalapeno',
#  521: 'steaks',
#  522: 'banana',
#  523: 'review',
#  524: 'movies',
#  525: 'coziness',
#  526: 'them',
#  527: 'meal',
#  528: 'offered',
#  529: 'claimed',
#  530: 'management',
#  531: 'Server',
#  532: 'greasy',
#  533: 'lighting',
#  534: 'caught',
#  535: 'theft',
#  536: 'We',
#  537: 'completely',
#  538: 'fireball',
#  539: 'combo',
#  540: 'andddd',
#  541: 'apologize',
#  542: 'hands-down',
#  543: 'fondue',
#  544: 'sunglasses',
#  545: 'pricey',
#  546: 'sucker',
#  547: 'inch',
#  548: 'itself',
#  549: 'Joey',
#  550: 'famous',
#  551: 'fan',
#  552: 'High-quality',
#  553: 'glad',
#  554: 'parties',
#  555: 'You',
#  556: 'Place',
#  557: 'gristle',
#  558: 'buffets',
#  559: 'operation',
#  560: 'him',
#  561: 'Stars',
#  562: 'profiterole',
#  563: 'dirt',
#  564: 'crowd',
#  565: 'speedy',
#  566: 'very',
#  567: 'worst',
#  568: 'offers',
#  569: 'letdown',
#  570: 'satifying',
#  571: '17',
#  572: 'neither',
#  573: 'shoe',
#  574: 'southwest',
#  575: 'Vegas',
#  576: 'highlight',
#  577: 'power',
#  578: 'girlfriend',
#  579: 'specials',
#  580: 'Subway',
#  581: 'paper',
#  582: 'six',
#  583: ')',
#  584: '30s',
#  585: 'charming',
#  586: 'do',
#  587: 'its',
#  588: 'caring',
#  589: 'TV',
#  590: 'pizzas',
#  591: 'enjoy',
#  592: 'unhealthy',
#  593: 'occasions',
#  594: 'weekend',
#  595: 'favorite',
#  596: 'Mom',
#  597: 'Of',
#  598: 'middle',
#  599: 'house',
#  600: 'found',
#  601: 'tartare',
#  602: 'thick',
#  603: 'contain',
#  604: 'plus',
#  605: 'guest',
#  606: 'verge',
#  607: 'at',
#  608: 'seal',
#  609: 'missing',
#  610: 'different',
#  611: 'added',
#  612: 'they',
#  613: 'plethora',
#  614: 'son',
#  615: 'bug',
#  616: 'needs',
#  617: 'funny',
#  618: 'sit-down',
#  619: 'everyone',
#  620: 'why',
#  621: 'finally',
#  622: 'used',
#  623: 'most',
#  624: 'of',
#  625: 'A',
#  626: 'Thus',
#  627: 'authentic',
#  628: 'Mmmm',
#  629: 'chai',
#  630: 'fair',
#  631: 'interesting',
#  632: 'inflate',
#  633: 'love',
#  634: 'hope',
#  635: 'Cotta',
#  636: 'Although',
#  637: 'first',
#  638: '8',
#  639: 'tater',
#  640: 'owned',
#  641: 'NONE',
#  642: 'guests',
#  643: 'fries',
#  644: 'Once',
#  645: 'joint',
#  646: 'setting',
#  647: 'alone',
#  648: 'lost',
#  649: 'dripping',
#  650: 'drastically',
#  651: 'smooth',
#  652: 'waiter',
#  653: 'taco',
#  654: 'mixed',
#  655: 'awkwardly',
#  656: 'Bacon',
#  657: 'customer',
#  658: 'HAPPENED',
#  659: 'drawing',
#  660: 'pneumatic',
#  661: 'Im',
#  662: 'THE',
#  663: 'having',
#  664: 'charge',
#  665: 'lighter',
#  666: 'pay',
#  667: 'work',
#  668: 'went',
#  669: 'crazy',
#  670: 'be',
#  671: 'tiny',
#  672: 'My',
#  673: 'breaks',
#  674: 'staying',
#  675: 'wash',
#  676: 'strange',
#  677: 'Today',
#  678: 'bone',
#  679: 'rare',
#  680: 'sexy',
#  681: 'Steiners',
#  682: 'shirt',
#  683: 'Heart',
#  684: 'Panna',
#  685: 'poor',
#  686: 'crêpe',
#  687: 'NOT',
#  688: 'fry',
#  689: 'soooooo',
#  690: 'cart',
#  691: 'petty',
#  692: 'military',
#  693: '40',
#  694: 'welcome',
#  695: 'favor',
#  696: 'covered',
#  697: 'bathrooms',
#  698: 'set',
#  699: 'array',
#  700: 'Frozen',
#  701: 'grill',
#  702: 'Caballero',
#  703: 'STEP',
#  704: 'read',
#  705: 'awesome',
#  706: 'sound',
#  707: 'say',
#  708: 'maybe',
#  709: 'Smashburger',
#  710: 'consider',
#  711: 'foot',
#  712: 'approval',
#  713: 'tots',
#  714: 'selection',
#  715: 'caterpillar',
#  716: 'Are',
#  717: 'TIME',
#  718: 'shoots',
#  719: 'Lox',
#  720: 'via',
#  721: 'pile',
#  722: 'nude',
#  723: 'peanut',
#  724: 'said',
#  725: 'bye',
#  726: 'lot',
#  727: 'neighborhood',
#  728: 'corn',
#  729: 'told',
#  730: 'excuse',
#  731: 'grow',
#  732: 'Jeff',
#  733: 'picture',
#  734: 'forth',
#  735: 'happened',
#  736: 'Nobu',
#  737: 'realized',
#  738: 'cheeseburger',
#  739: 'plain',
#  740: 'bathroom',
#  741: 'basically',
#  742: 'Steak',
#  743: 'white',
#  744: 'Gold',
#  745: 'unprofessional',
#  746: 'seated',
#  747: 'eat',
#  748: 'eel',
#  749: 'Café',
#  750: 'dreamed',
#  751: 'almost',
#  752: 'mmmm',
#  753: 'disgraceful',
#  754: 'been',
#  755: 'Generous',
#  756: 'AYCE',
#  757: 'delicate',
#  758: 'revisiting',
#  759: 'wish',
#  760: 'juice',
#  761: 'Owner',
#  762: 'Service',
#  763: 'bruschetta',
#  764: 'bigger',
#  765: 'vegetables',
#  766: 'ok',
#  767: 'tummy',
#  768: 'croutons',
#  769: 'folks',
#  770: 'friendly',
#  771: 'rings',
#  772: 'fiancé',
#  773: 'dollars',
#  774: 'generic',
#  775: 'she',
#  776: 'SCREAMS',
#  777: 'Dylan',
#  778: 'evening',
#  779: 'acknowledged',
#  780: 'capers',
#  781: 'person',
#  782: 'Cibo',
#  783: 'call',
#  784: 'driest',
#  785: 'AVOID',
#  786: 'double',
#  787: 'rate',
#  788: 'send',
#  789: 'strings',
#  790: 'bits',
#  791: 'reading',
#  792: 'Denny',
#  793: 'coupons',
#  794: 'Come',
#  795: 'degree',
#  796: 'waitresses',
#  797: 'touch',
#  798: '/hand',
#  799: 'over-hip',
#  800: '11.99',
#  801: 'held',
#  802: 'end',
#  803: 'subpar',
#  804: 'gooodd',
#  805: 'polite',
#  806: 'stuffed',
#  807: 'madhouse',
#  808: 'kept',
#  809: 'edible',
#  810: 'color',
#  811: 'ate',
#  812: 'chips',
#  813: 'privileged',
#  814: 'else',
#  815: 'Could',
#  816: 'IN',
#  817: 'Try',
#  818: 'decorated',
#  819: 'car',
#  820: 'inside',
#  821: 'hummus',
#  822: 'does',
#  823: 'contained',
#  824: 'below',
#  825: 'bite',
#  826: 'quick',
#  827: 'EVER',
#  828: 'arriving',
#  829: 'truffle',
#  830: 'Casino',
#  831: 'industry',
#  832: 'dressing',
#  833: 'hankering',
#  834: 'poorly',
#  835: 'Cant',
#  836: 'decor',
#  837: 'employees',
#  838: 'Do',
#  839: 'martini',
#  840: 'owner/chef',
#  841: 'pleasant',
#  842: 'unexperienced',
#  843: 'mile',
#  844: 'ratio',
#  845: 'mouth',
#  846: 'roasted',
#  847: '...',
#  848: 'or',
#  849: 'delightful',
#  850: 'cavier',
#  851: 'lawyers',
#  852: 'especially',
#  853: 'coconut',
#  854: 'also',
#  855: 'daughter',
#  856: 'mayo',
#  857: 'rotating',
#  858: 'ended',
#  859: 'cooked',
#  860: 'Went',
#  861: 'steak',
#  862: 'place',
#  863: 'Voodoo',
#  864: 'BARE',
#  865: 'flirting',
#  866: 'great',
#  867: 'overwhelmed',
#  868: 'stale',
#  869: 'Chinese',
#  870: 'super',
#  871: 'Burrittos',
#  872: 'menu',
#  873: 'frozen',
#  874: 'eggs',
#  875: 'MGM',
#  876: 'pasta',
#  877: 'make',
#  878: 'APPETIZERS',
#  879: 'profound',
#  880: 'Mary',
#  881: 'real',
#  882: 'life',
#  883: 'instead',
#  884: 'Please',
#  885: 'seasonal',
#  886: 'full',
#  887: '$',
#  888: 'husband',
#  889: 'medium',
#  890: 'reasons',
#  891: 'Han',
#  892: 'powdered',
#  893: 'For',
#  894: 'screwed',
#  895: 'new',
#  896: 'Eew',
#  897: 'grocery',
#  898: 'Go',
#  899: 'pats',
#  900: 'loyal',
#  901: 'raspberry',
#  902: 'First',
#  903: 'none',
#  904: 'than',
#  905: 'nasty',
#  906: 'themselves',
#  907: 'patty',
#  908: 'batch',
#  909: 'hopes',
#  910: 'After',
#  911: 'either',
#  912: 'sat',
#  913: 'since',
#  914: 'truly',
#  915: 'group',
#  916: 'vomited',
#  917: 'come',
#  918: 'years',
#  919: 'refused',
#  920: 'dont',
#  921: 'NO',
#  922: 'Sooooo',
#  923: 'may',
#  924: 'job',
#  925: 'Strike',
#  926: 'tolerance',
#  927: 'winner',
#  928: 'rolls',
#  929: '90',
#  930: 'appealing',
#  931: 'opposed',
#  932: 'hair',
#  933: 'tender',
#  934: 'meet',
#  935: 'dessert',
#  936: 'apart',
#  937: 'suggestions',
#  938: 'Back',
#  939: 'lacked',
#  940: 'biscuit',
#  941: 'date',
#  942: 'trying',
#  943: '-My',
#  944: 'One',
#  945: 'Baba',
#  946: 'fact',
#  947: 'by',
#  948: 'AN',
#  949: 'douchey',
#  950: 'eggplant',
#  951: 'simple',
#  952: 'fella',
#  953: 'An',
#  954: 'baby',
#  955: 'Perhaps',
#  956: '.',
#  957: 'oh',
#  958: 'haunt',
#  959: 'waiting',
#  960: 'greeted',
#  961: 'happier',
#  962: 'somewhat',
#  963: 'toro',
#  964: 'grandmother',
#  965: 'imaginative',
#  966: 'smells',
#  967: 'music',
#  968: 'done',
#  969: 'letting',
#  970: 'during',
#  971: 'outside',
#  972: 'guy',
#  973: 'OK',
#  974: 'located',
#  975: 'cheap',
#  976: 'were',
#  977: 'rib',
#  978: 'Hot',
#  979: 'cut',
#  980: 'cheesecurds',
#  981: 'compliments',
#  982: 'ala',
#  983: 'Sauce',
#  984: 'disappointing',
#  985: 'deep',
#  986: 'proven',
#  987: 'May',
#  988: 'Aria',
#  989: 'drinks',
#  990: 'couple',
#  991: 'exquisite',
#  992: 'greatest',
#  993: 'moz',
#  994: 'hit',
#  995: 'under',
#  996: 'opinion',
#  997: 'stir',
#  998: 'hooked',
#  999: 'imagine',
#  ...}

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    '''創建一個vector'''
    vector = np.zeros(len(whole_words))
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            vector[word_index[word]] += 1
            
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
_get_bag_of_words_vector('sample is an Indian restaurant.', word_index, whole_words)
# Out:
# array([1., 1., 0., ..., 0., 0., 0.])
